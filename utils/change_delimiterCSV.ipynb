# %%
 # Mount drive - always run 1st 
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import csv

reader = csv.reader(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/Talkdesk_interaction-analytics-search_results_20220901-11-59-46.csv", "r"), delimiter=',')
writer = csv.writer(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/Talkdesk_interaction.csv", 'w'), delimiter=';')
writer.writerows(reader)

print("Delimiter successfully changed")
# Out:
# Delimiter successfully changed

# %%
reader = csv.reader(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/tweetsum.csv", "r"), delimiter=',')
writer = csv.writer(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/Talkdesk_tweets.csv", 'w'), delimiter=';')
writer.writerows(reader)

print("Delimiter successfully changed")
# Out:
# Delimiter successfully changed

# %%
reader = csv.reader(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/dialogsum_100_sample.csv", "r"), delimiter=',')
writer = csv.writer(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/Talkdesk_dialogsum100.csv", 'w'), delimiter=';')
writer.writerows(reader)

print("Delimiter successfully changed")
# Out:
# Delimiter successfully changed

# %%
reader = csv.reader(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/dialogsum.csv", "r"), delimiter=',')
writer = csv.writer(open("/content/drive/MyDrive/ColabNotebooks/datasets/Talkdesk/Talkdesk_dialogsum.csv", 'w'), delimiter=';')
writer.writerows(reader)

print("Delimiter successfully changed")
# Out:
# Delimiter successfully changed
